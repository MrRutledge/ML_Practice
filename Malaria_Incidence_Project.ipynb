# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
import pandas as pd 
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
#from fastai.imports import *

# %%
# !cd

# %%
data = pd.read_csv('Datasets/Africa_Vectors_database_1898-2016.csv', encoding='latin-1')

# %%
data.head(1)
# Out:
#   Country GAUL_Admin1 GAUL_Admin2       Full_Name    Lat    Long  \
# 0  Angola       Bengo       Dande  Barra do Dande -8.473  13.362
#
#   LatLong_Source  YeStart  YeEnd An gambiae_complex  ... An rufipes  \
# 0        Encarta     1967   1967                  Y  ...        NaN
#
#   An coustani s.l An ziemanni  An paludis    Adults/Larvae Sampling_Methods  \
# 0             NaN          NaN         NaN  Adults, Larvae     HLC, HBC, LC
#
#   Species_Identification Other sib species names Other Anopheline species  \
# 0                      M                     NaN                      NaN
#
#                                         Source_Title
# 0  Ribeiro H & Ramos HC (1975). Research on the m...
#
# [1 rows x 41 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13464 entries, 0 to 13463
# Data columns (total 41 columns):
# Country                                   13464 non-null object
# GAUL_Admin1                               13364 non-null object
# GAUL_Admin2                               13075 non-null object
# Full_Name                                 13464 non-null object
# Lat                                       13330 non-null float64
# Long                                      13330 non-null float64
# LatLong_Source                            13331 non-null object
# YeStart                                   13464 non-null int64
# YeEnd                                     13464 non-null int64
# An gambiae_complex                        11596 non-null object
# An gambiae ss                             3990 non-null object
# SS M Form (An colluzzi or Mopti forms)    1331 non-null object
# SS S Form (savanah or Bamako forms)       1575 non-null object
# An arabiensis                             3648 non-null object
# An. melas                                 538 non-null object
# An. merus                                 254 non-null object
# An bwambae                                26 non-null object
# An funestus  s.l                          5095 non-null object
# An funestus s.s. (specified)              727 non-null object
# An rivulorum                              245 non-null object
# An leesoni                                188 non-null object
# An parensis                               41 non-null object
# An vaneedeni                              34 non-null object
# An nili s.l                               823 non-null object
# An moucheti s.l                           502 non-null object
# An pharoensis                             1902 non-null object
# An hancocki                               298 non-null object
# An mascarensis                            483 non-null object
# An marshalli                              444 non-null object
# An squamous                               1294 non-null object
# An wellcomei                              272 non-null object
# An rufipes                                999 non-null object
# An coustani s.l                           2692 non-null object
# An ziemanni                               663 non-null object
# An paludis                                376 non-null object
# Adults/Larvae                             13464 non-null object
# Sampling_Methods                          13464 non-null object
# Species_Identification                    13464 non-null object
# Other sib species names                   259 non-null object
# Other Anopheline species                  3118 non-null object
# Source_Title                              13464 non-null object
# dtypes: float64(2), int64(2), object(37)
# memory usage: 4.2+ MB

# %%
data.sample
# Out:
# <bound method NDFrame.sample of         Country         GAUL_Admin1    GAUL_Admin2  \
# 0        Angola               Bengo          Dande
# 1        Angola               Bengo          Dande
# 2        Angola               Bengo          Dande
# 3        Angola               Bengo          Dande
# 4        Angola               Bengo         Dembos
# 5        Angola               Bengo  Icolo E Bengo
# 6        Angola               Bengo  Icolo E Bengo
# 7        Angola               Bengo  Icolo E Bengo
# 8        Angola               Bengo  Icolo E Bengo
# 9        Angola               Bengo  Icolo E Bengo
# 10       Angola               Bengo       Quissama
# 11       Angola               Bengo       Quissama
# 12       Angola               Bengo       Quissama
# 13       Angola            Benguela     Baia Farta
# 14       Angola            Benguela        Balombo
# 15       Angola            Benguela        Balombo
# 16       Angola            Benguela        Balombo
# 17       Angola            Benguela        Balombo
# 18       Angola            Benguela        Balombo
# 19       Angola            Benguela        Balombo
# 20       Angola            Benguela       Benguela
# 21       Angola            Benguela       Benguela
# 22       Angola            Benguela       Benguela
# 23       Angola            Benguela       Benguela
# 24       Angola            Benguela         Bocoio
# 25       Angola            Benguela      Caimbambo
# 26       Angola            Benguela          Cubal
# 27       Angola            Benguela          Ganda
# 28       Angola            Benguela          Ganda
# 29       Angola            Benguela         Lobito
# ...         ...                 ...            ...
# 13434  Zimbabwe  Matabeleland North          Binga
# 13435  Zimbabwe  Matabeleland North          Binga
# 13436  Zimbabwe  Matabeleland North          Binga
# 13437  Zimbabwe  Matabeleland North          Binga
# 13438  Zimbabwe  Matabeleland North         Hwange
# 13439  Zimbabwe  Matabeleland North         Hwange
# 13440  Zimbabwe  Matabeleland North         Hwange
# 13441  Zimbabwe  Matabeleland North         Hwange
# 13442  Zimbabwe  Matabeleland North         Hwange
# 13443  Zimbabwe  Matabeleland North         Hwange
# 13444  Zimbabwe  Matabeleland North         Hwange
# 13445  Zimbabwe  Matabeleland North         Lupane
# 13446  Zimbabwe  Matabeleland North         Lupane
# 13447  Zimbabwe  Matabeleland South     Beitbridge
# 13448  Zimbabwe  Matabeleland South     Beitbridge
# 13449  Zimbabwe  Matabeleland South     Beitbridge
# 13450  Zimbabwe  Matabeleland South         Mangwe
# 13451  Zimbabwe  Matabeleland South     Umzingwane
# 13452  Zimbabwe            Midlands    Gokwe North
# 13453  Zimbabwe            Midlands    Gokwe North
# 13454  Zimbabwe            Midlands    Gokwe North
# 13455  Zimbabwe            Midlands    Gokwe North
# 13456  Zimbabwe            Midlands    Gokwe South
# 13457  Zimbabwe            Midlands    Gokwe South
# 13458  Zimbabwe            Midlands    Gokwe South
# 13459  Zimbabwe            Midlands    Gokwe South
# 13460  Zimbabwe            Midlands    Gokwe South
# 13461  Zimbabwe            Midlands          Gweru
# 13462  Zimbabwe            Midlands         Kwekwe
# 13463  Zimbabwe            Midlands      Mberengwa
#
#                         Full_Name      Lat     Long LatLong_Source  YeStart  \
# 0                  Barra do Dande  -8.4730  13.3620        Encarta     1967
# 1                       Boa Vista  -8.5990  13.5660        Encarta     1987
# 2                         Cabungo  -8.5667  13.5000          Other     2002
# 3                          Lifune  -8.4000  13.4490        Encarta     1970
# 4                          Dembos  -8.5156  14.5189   Google Earth     1940
# 5                       Bom Jesus  -9.1660  13.5660        Encarta     1952
# 6                   Icolo e Bengo  -9.2500  13.7333          Other     1940
# 7                         Kilunda  -8.9268  13.5878          Other     2001
# 8                     Lagoa Banda  -8.8503  13.5842   Google Earth     1965
# 9                          Mazozo  -9.1020  13.6220        Encarta     1970
# 10                       Mumbondo -10.1810  14.1290        Encarta     1970
# 11                         Muxima  -9.5206  13.9589   Google Earth     1970
# 12                       Quissama  -9.7984  13.7289   Google Earth     1940
# 13                       Equimina -13.1990  12.7930        Encarta     1969
# 14                       Barragem -12.3390  14.7892    Combination     2008
# 15                       Candiero -12.3665  14.7610    Combination     2008
# 16                        Canjala -12.3547  14.7365    Combination     2008
# 17                        Capango -12.3836  14.8332   Google Earth     2008
# 18                    Chissequele -12.3634  14.7832    Combination     2008
# 19                         Libata -12.3390  14.7673    Combination     2008
# 20                         Cavaco -12.5433  13.4308       GeoNames     2005
# 21                        Cawango -12.5689  13.4034    Combination     2001
# 22                         Lobito -12.5740  13.4030        Encarta     1963
# 23                      Sao Pedro -12.7150  13.4670        Encarta     2001
# 24                         Bocoio -12.4630  14.1660        Encarta     1970
# 25                    Cui (Sumbo) -13.4000  13.9667       GeoNames     1970
# 26                          Cubal -13.0400  14.2470        Encarta     1970
# 27                         Ebanga -12.7330  14.7340        Encarta     1970
# 28                          Ganda -13.0280  14.6340        Encarta     1952
# 29                      Alto Liro -12.3480  13.5985    Combination     2003
# ...                           ...      ...      ...            ...      ...
# 13434                       Binga -17.6247  27.3420        Encarta     1978
# 13435                     Manjolo -17.6225  27.3416            GPS     2012
# 13436                      Mlibzi -18.0397  27.1238   Google Earth     1974
# 13437                Saba Springs -18.0136  27.1358       Geonames     1999
# 13438                    Chilonga -18.4000  27.1667       GeoNames     1962
# 13439                        Deka -18.0828  26.7178   Google Earth     1974
# 13440       Deka river confluence -18.0667  26.7167          Other     1974
# 13441                      Hwange -18.3559  26.5020   Google Earth     1999
# 13442         Matetsi River mouth -17.8672  25.5025   Google Earth     1975
# 13443  Victoria Falls resort town -17.9283  25.8378   Google Earth     1999
# 13444             Wankie Colliery -18.3541  26.5010   Google Earth     1999
# 13445               Gwaai Reserve -19.1429  27.7570       GeoNames     1957
# 13446                    Jotsholo -18.7184  27.5563   Google Earth     1999
# 13447                  Beitbridge -22.2064  29.9975        Encarta     2013
# 13448                 Makakavhule -21.8271  30.4384            GPS     2012
# 13449                      Matibi -22.0765  30.6492   Google Earth     1974
# 13450                      Marula -20.4832  28.0830   Google Earth     1944
# 13451                   Essexvale -20.2911  28.9392   Google Earth     1940
# 13452                     Chireya -17.5522  28.6038   Google Earth     1994
# 13453                Copper Queen -17.5167  29.3333          Other     1926
# 13454                   Masakadza -17.6666  28.3167       Geonames     1999
# 13455                  Nembudziya -17.7214  29.0082   Google Earth     1995
# 13456                       Gokwe -18.2167  28.9338   Google Earth     1999
# 13457                 Gokwe South -18.2400  28.6500       Geonames     2013
# 13458                       Gwave -17.9000  28.7000       GeoNames     2006
# 13459                   Kamhororo -18.2189  28.9406            GPS     1993
# 13460          Matsakinya Springs -17.9413  28.2121    Combination     1999
# 13461                       Gwelo -19.4683  29.8122   Google Earth     1940
# 13462                      Kwekwe -18.9201  29.8237   Google Earth     1940
# 13463            Belingwe Reserve -20.5495  29.9132   Google Earth     1956
#
#        YeEnd An gambiae_complex  ... An rufipes An coustani s.l An ziemanni   \
# 0       1967                  Y  ...        NaN             NaN          NaN
# 1       1987                  Y  ...        NaN             NaN          NaN
# 2       2002                  Y  ...        NaN             NaN          NaN
# 3       1970                NaN  ...        NaN               Y            Y
# 4       1940                  Y  ...        NaN             NaN          NaN
# 5       1955                NaN  ...        NaN               Y            Y
# 6       1940                  Y  ...        NaN             NaN          NaN
# 7       2002                NaN  ...        NaN             NaN          NaN
# 8       1965                  Y  ...        NaN               Y            Y
# 9       1970                  Y  ...        NaN             NaN          NaN
# 10      1970                NaN  ...        NaN               Y            Y
# 11      1970                  Y  ...        NaN               Y            Y
# 12      1940                  Y  ...        NaN             NaN          NaN
# 13      1970                  Y  ...        NaN             NaN          NaN
# 14      2009                  Y  ...        NaN               Y            Y
# 15      2009                  Y  ...        NaN               Y            Y
# 16      2009                  Y  ...        NaN               Y            Y
# 17      2009                  Y  ...        NaN               Y            Y
# 18      2009                  Y  ...        NaN               Y            Y
# 19      2009                  Y  ...        NaN               Y            Y
# 20      2005                  Y  ...        NaN             NaN          NaN
# 21      2001                  Y  ...        NaN             NaN          NaN
# 22      2006                  Y  ...        NaN               Y            Y
# 23      2001                  Y  ...        NaN             NaN          NaN
# 24      1970                  Y  ...          Y               Y          NaN
# 25      1970                  Y  ...        NaN             NaN          NaN
# 26      1970                  Y  ...          Y               Y          NaN
# 27      1970                NaN  ...          Y               Y            Y
# 28      1955                NaN  ...          Y             NaN          NaN
# 29      2005                  Y  ...        NaN             NaN          NaN
# ...      ...                ...  ...        ...             ...          ...
# 13434   2014                  Y  ...        NaN             NaN          NaN
# 13435   2012                  Y  ...        NaN             NaN          NaN
# 13436   1974                  Y  ...        NaN             NaN          NaN
# 13437   2002                  Y  ...        NaN             NaN          NaN
# 13438   2014                  Y  ...          Y               Y          NaN
# 13439   1974                  Y  ...        NaN             NaN          NaN
# 13440   1975                  Y  ...        NaN             NaN          NaN
# 13441   2002                NaN  ...        NaN             NaN          NaN
# 13442   1975                  Y  ...        NaN             NaN          NaN
# 13443   2002                NaN  ...        NaN             NaN          NaN
# 13444   2002                  Y  ...        NaN             NaN          NaN
# 13445   1957                NaN  ...        NaN             NaN          NaN
# 13446   2012                  Y  ...        NaN             NaN          NaN
# 13447   2014                  Y  ...        NaN             NaN          NaN
# 13448   2014                  Y  ...        NaN             NaN          NaN
# 13449   1974                  Y  ...        NaN             NaN          NaN
# 13450   1944                NaN  ...        NaN             NaN          NaN
# 13451   1956                NaN  ...        NaN             NaN          NaN
# 13452   1994                  Y  ...        NaN             NaN          NaN
# 13453   1928                  Y  ...        NaN             NaN          NaN
# 13454   2002                  Y  ...        NaN             NaN          NaN
# 13455   1996                  Y  ...        NaN             NaN          NaN
# 13456   2012                  Y  ...          Y               Y          NaN
# 13457   2014                  Y  ...        NaN             NaN          NaN
# 13458   2008                  Y  ...        NaN               Y          NaN
# 13459   2012                  Y  ...        NaN             NaN          NaN
# 13460   2002                  Y  ...        NaN             NaN          NaN
# 13461   1956                NaN  ...        NaN             NaN          NaN
# 13462   2002                  Y  ...        NaN             NaN          NaN
# 13463   1956                NaN  ...        NaN             NaN          NaN
#
#       An paludis    Adults/Larvae  \
# 0             NaN  Adults, Larvae
# 1             NaN  Adults, Larvae
# 2             NaN          Adults
# 3             NaN  Adults, Larvae
# 4             NaN         Unknown
# 5             NaN          Adults
# 6             NaN         Unknown
# 7             NaN          Adults
# 8             NaN  Adults, Larvae
# 9             NaN  Adults, Larvae
# 10            NaN  Adults, Larvae
# 11            NaN  Adults, Larvae
# 12            NaN         Unknown
# 13            NaN  Adults, Larvae
# 14            NaN          Adults
# 15            NaN          Adults
# 16            NaN          Adults
# 17            NaN          Adults
# 18            NaN          Adults
# 19            NaN          Adults
# 20            NaN          Adults
# 21            NaN          Adults
# 22            NaN  Adults, Larvae
# 23            NaN          Adults
# 24            NaN  Adults, Larvae
# 25            NaN  Adults, Larvae
# 26            NaN  Adults, Larvae
# 27            NaN  Adults, Larvae
# 28            NaN          Larvae
# 29            NaN  Adults, Larvae
# ...           ...             ...
# 13434         NaN  Adults, Larvae
# 13435         NaN          Larvae
# 13436         NaN          Adults
# 13437         NaN  Adults, Larvae
# 13438         NaN          Adults
# 13439         NaN          Adults
# 13440         NaN          Adults
# 13441         NaN  Adults, Larvae
# 13442         NaN          Adults
# 13443         NaN  Adults, Larvae
# 13444         NaN  Adults, Larvae
# 13445         NaN  Adults, Larvae
# 13446         NaN  Adults, Larvae
# 13447         NaN          Adults
# 13448         NaN  Adults, Larvae
# 13449         NaN          Adults
# 13450         NaN  Adults, Larvae
# 13451         NaN  Adults, Larvae
# 13452         NaN          Adults
# 13453         NaN  Adults, Larvae
# 13454         NaN  Adults, Larvae
# 13455         NaN          Adults
# 13456         NaN  Adults, Larvae
# 13457         NaN          Adults
# 13458         NaN  Adults, Larvae
# 13459         NaN  Adults, Larvae
# 13460         NaN  Adults, Larvae
# 13461         NaN  Adults, Larvae
# 13462         NaN  Adults, Larvae
# 13463         NaN  Adults, Larvae
#
#                                    Sampling_Methods  \
# 0                                      HLC, HBC, LC
# 1                                           PSC, LC
# 2                                  IR, Bednet traps
# 3                                      HLC, ABC, LC
# 4                                           Unknown
# 5                                           IR, HLC
# 6                                           Unknown
# 7                                                IR
# 8                                 HLC, HBC, ABC, LC
# 9                                      HLC, ABC, LC
# 10                                     HLC, ABC, LC
# 11                                HLC, HBC, ABC, LC
# 12                                          Unknown
# 13                                     HLC, HBC, LC
# 14                                   CDC Light trap
# 15                                   CDC Light trap
# 16                                   CDC Light trap
# 17                                   CDC Light trap
# 18                                   CDC Light trap
# 19                                   CDC Light trap
# 20                                 IR, Bednet traps
# 21                                              PSC
# 22                           IR,CDC Light traps, LC
# 23                                              PSC
# 24                                HLC, HBC, ABC, LC
# 25                                     HLC, HBC, LC
# 26                                HLC, HBC, ABC, LC
# 27                                     HLC, ABC, LC
# 28                                               LC
# 29                                          HLC, LC
# ...                                             ...
# 13434              IR, HLC, Exit traps, ABC, OS, LC
# 13435                                            LC
# 13436                                       Unknown
# 13437              IR, HLC, Exit traps, ABC, OS, LC
# 13438            IR, HLC, ABC, CDC Light traps, PSC
# 13439                                            OS
# 13440                                           PSC
# 13441              IR, HLC, Exit traps, ABC, OS, LC
# 13442                                           PSC
# 13443              IR, HLC, Exit traps, ABC, OS, LC
# 13444              IR, HLC, Exit traps, ABC, OS, LC
# 13445                                    IR, OS, LC
# 13446              IR, HLC, Exit traps, ABC, OS, LC
# 13447                                            IR
# 13448                                   PSC, IR, LC
# 13449                                           PSC
# 13450                                    IR, OS, LC
# 13451                                    IR, OS, LC
# 13452                    Pit traps, HBC, Exit traps
# 13453                                    IR, OS, LC
# 13454              IR, HLC, Exit traps, ABC, OS, LC
# 13455                    Pit traps, HBC, Exit traps
# 13456              IR, HLC, Exit traps, ABC, OS, LC
# 13457                                            IR
# 13458  Man-bait tent traps, Exit traps, IR, ABC, LC
# 13459                Pit traps, HBC, Exit traps, LC
# 13460              IR, HLC, Exit traps, ABC, OS, LC
# 13461                                    IR, OS, LC
# 13462              IR, HLC, Exit traps, ABC, OS, LC
# 13463                                    IR, OS, LC
#
#                Species_Identification Other sib species names  \
# 0                                   M                     NaN
# 1                                   M                     NaN
# 2                              M, PCR                     NaN
# 3                                   M                     NaN
# 4                                   M                     NaN
# 5                                   M                     NaN
# 6                                   M                     NaN
# 7                              M, CBS                     NaN
# 8                                   M                     NaN
# 9                                   M                     NaN
# 10                                  M                     NaN
# 11                                  M  An wellcomei wellcomei
# 12                                  M                     NaN
# 13                                  M                     NaN
# 14                                  M                     NaN
# 15                                  M                     NaN
# 16                                  M                     NaN
# 17                                  M                     NaN
# 18                                  M                     NaN
# 19                                  M                     NaN
# 20                             M, PCR                     NaN
# 21                             M, PCR                     NaN
# 22                             M, PCR                     NaN
# 23                             M, PCR                     NaN
# 24                         M, Unknown                     NaN
# 25                                  M                     NaN
# 26                         M, Unknown                     NaN
# 27                         M, Unknown                     NaN
# 28                                  M                     NaN
# 29                             M, PCR                     NaN
# ...                               ...                     ...
# 13434                          M, PCR                     NaN
# 13435                               M                     NaN
# 13436                          M, CBS                     NaN
# 13437                          M, PCR                     NaN
# 13438                     M, CBS, DNA                     NaN
# 13439  M, CBS, Enzyme electrophoresis                     NaN
# 13440                          M, CBS                     NaN
# 13441                          M, PCR                     NaN
# 13442                          M, CBS                     NaN
# 13443                          M, PCR                     NaN
# 13444                          M, PCR                     NaN
# 13445                               M                     NaN
# 13446                          M, PCR                     NaN
# 13447                               M                     NaN
# 13448                               M                     NaN
# 13449                          M, CBS                     NaN
# 13450                               M                     NaN
# 13451                               M                     NaN
# 13452                               M                     NaN
# 13453                               M                     NaN
# 13454                          M, PCR                     NaN
# 13455                               M                     NaN
# 13456                          M, PCR                     NaN
# 13457                               M                     NaN
# 13458                          M, PCR                     NaN
# 13459                          M, PCR                     NaN
# 13460                          M, PCR                     NaN
# 13461                               M                     NaN
# 13462                          M, PCR                     NaN
# 13463                               M                     NaN
#
#                                 Other Anopheline species  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                           An obscurus
# 11                                                   NaN
# 12                                                   NaN
# 13                           An rhodesiensis, An listeri
# 14                        An maculipalpis, An tenebrosus
# 15                        An maculipalpis, An tenebrosus
# 16                        An maculipalpis, An tenebrosus
# 17                        An maculipalpis, An tenebrosus
# 18                        An maculipalpis, An tenebrosus
# 19                        An maculipalpis, An tenebrosus
# 20                                                   NaN
# 21                                                   NaN
# 22                                            An listeri
# 23                                                   NaN
# 24     An rhodesiensis, An demeilloni, An longipalpis...
# 25                                                   NaN
# 26     An rhodesiensis, An maculipalpis, An pretorien...
# 27     An tenebrosus, An ardensis, An rhodesiensis, A...
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 13434                   An maculipalpis, An rhodesiensis
# 13435                                                NaN
# 13436                                                NaN
# 13437                                                NaN
# 13438                An pretoriensis, An quadriannulatus
# 13439                                                NaN
# 13440                                 An quadriannulatus
# 13441                                    An pretoriensis
# 13442                                 An quadriannulatus
# 13443                                    An pretoriensis
# 13444                                 An quadriannulatus
# 13445                                         An listeri
# 13446                                                NaN
# 13447                                                NaN
# 13448                                                NaN
# 13449                                 An quadriannulatus
# 13450                                    An rhodesiensis
# 13451                                      An natalensis
# 13452                                                NaN
# 13453                                                NaN
# 13454                                                NaN
# 13455                                                NaN
# 13456                                                NaN
# 13457                                                NaN
# 13458                 An longipalpis, An quadriannulatus
# 13459                                                NaN
# 13460                                                NaN
# 13461                                        An garnhami
# 13462                                 An quadriannulatus
# 13463                  An argenteolobutus, An distinctus
#
#                                             Source_Title
# 0      Ribeiro H & Ramos HC (1975). Research on the m...
# 1      Ramos L (1988). Memorandum sent to Director Ge...
# 2      Calzetta M, Santolamazza F, Carrara GC, Cani P...
# 3      Ribeiro H & Ramos HC (1975). Research on the m...
# 4      De Mesquita B (1942). Consideraes sobre o im...
# 5      Gandara AF (1956). Subsido para o estude dos '...
# 6      Ribiero L (1942). Notas sobre aspectos nosogra...
# 7      Boccolini D, Carrara GC, Dia I, Fortes F, Cani...
# 8      Ribeiro H & Ramos HC (1975). Research on the m...
# 9      Ribeiro H & Ramos HC (1975). Research on the m...
# 10     Ribeiro H & Ramos HC (1975). Research on the m...
# 11     Ribeiro H & Ramos HC (1975). Research on the m...
# 12     De Mesquita B (1942). Consideraes sobre o im...
# 13     Ribeiro H & Ramos HC (1975). Research on the m...
# 14     Brosseau L, Drame PM, Besnard P, Toto JC, Foum...
# 15     Brosseau L, Drame PM, Besnard P, Toto JC, Foum...
# 16     Brosseau L, Drame PM, Besnard P, Toto JC, Foum...
# 17     Brosseau L, Drame PM, Besnard P, Toto JC, Foum...
# 18     Brosseau L, Drame PM, Besnard P, Toto JC, Foum...
# 19     Brosseau L, Drame PM, Besnard P, Toto JC, Foum...
# 20     Calzetta M, Santolamazza F, Carrara GC, Cani P...
# 21     Choi KS & Townson H (2012). Evidence for X-lin...
# 22     Ribeiro H, Casaca VMR, Cochofel JALP (1964). A...
# 23     Choi KS & Townson H (2012). Evidence for X-lin...
# 24     Ribeiro H & Ramos HC (1975). Research on the m...
# 25     Ribeiro H & Ramos HC (1975). Research on the m...
# 26     Ribeiro H & Ramos HC (1975). Research on the m...
# 27     Ribeiro H & Ramos HC (1975). Research on the m...
# 28     Gandara AF (1956). Subsido para o estude dos '...
# 29     Toto JC, Besnard P, Le Mire J, Almeida DS, Dos...
# ...                                                  ...
# 13434  Green CA & Hunt RH (1980). Interpretation of v...
# 13435  Lukwa N, Sande S, Makuwaza A, Chiwade T, Netsa...
# 13436  Coetzee M, Hunt RH, Braak LEO, Davidson G (199...
# 13437  Masendu HT, Hunt RH, Koekemoer LL, Brooke BD, ...
# 13438  McIntosh BM, Harwin RM, Paterson HE, Westwater...
# 13439  Mahon RJ, Green CA, Hunt RH (1976). Diagnostic...
# 13440  Hunt RH & Mahon RJ (1986). Collections of Anop...
# 13441  Masendu HT, Hunt RH, Koekemoer LL, Brooke BD, ...
# 13442  Coetzee M, Hunt RH, Braak LEO, Davidson G (199...
# 13443  Masendu HT, Hunt RH, Koekemoer LL, Brooke BD, ...
# 13444  Masendu HT, Hunt RH, Koekemoer LL, Brooke BD, ...
# 13445  Reid ET & Woods RW (1957). Anopheline mosquito...
# 13446  Lukwa N, Sande S, Makuwaza A, Chiwade T, Netsa...
# 13447  Fornadel C & Norris L (2015). PresidentÕs Mala...
# 13448  Lukwa N, Sande S, Makuwaza A, Chiwade T, Netsa...
# 13449  Coetzee M, Hunt RH, Braak LEO, Davidson G (199...
# 13450  Reid ET & Woods RW (1957). Anopheline mosquito...
# 13451  Reid ET & Woods RW (1957). Anopheline mosquito...
# 13452  Manokore V, Murahwa FC, Chirebvu E (2000). Abs...
# 13453  Leeson HS (1931). Anopheline Mosquitos in Sout...
# 13454  Masendu HT, Hunt RH, Koekemoer LL, Brooke BD, ...
# 13455  Manokore V, Murahwa FC, Chirebvu E (2000). Abs...
# 13456  Lukwa N, Sande S, Makuwaza A, Chiwade T, Netsa...
# 13457  Fornadel C & Norris L (2015). PresidentÕs Mala...
# 13458  Munhenga G (2010). Characterisation of resista...
# 13459  Manokore V, Murahwa FC, Chirebvu E (2000). Abs...
# 13460  Masendu HT, Hunt RH, Koekemoer LL, Brooke BD, ...
# 13461  Reid ET & Woods RW (1957). Anopheline mosquito...
# 13462  Masendu HT, Hunt RH, Koekemoer LL, Brooke BD, ...
# 13463  Reid ET & Woods RW (1957). Anopheline mosquito...
#
# [13464 rows x 41 columns]>

# %%
(data.count() == 13464)
# Out:
# Country                                    True
# GAUL_Admin1                               False
# GAUL_Admin2                               False
# Full_Name                                  True
# Lat                                       False
# Long                                      False
# LatLong_Source                            False
# YeStart                                    True
# YeEnd                                      True
# An gambiae_complex                        False
# An gambiae ss                             False
# SS M Form (An colluzzi or Mopti forms)    False
# SS S Form (savanah or Bamako forms)       False
# An arabiensis                             False
# An. melas                                 False
# An. merus                                 False
# An bwambae                                False
# An funestus  s.l                          False
# An funestus s.s. (specified)              False
# An rivulorum                              False
# An leesoni                                False
# An parensis                               False
# An vaneedeni                              False
# An nili s.l                               False
# An moucheti s.l                           False
# An pharoensis                             False
# An hancocki                               False
# An mascarensis                            False
# An marshalli                              False
# An squamous                               False
# An wellcomei                              False
# An rufipes                                False
# An coustani s.l                           False
# An ziemanni                               False
# An paludis                                False
# Adults/Larvae                              True
# Sampling_Methods                           True
# Species_Identification                     True
# Other sib species names                   False
# Other Anopheline species                  False
# Source_Title                               True
# dtype: bool

# %% [markdown]
# data.isnull()
